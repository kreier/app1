# %% [markdown]
# #Question from AP Physics 1 Unit 5 Momentum

# %%
m = 0.15
F = 480
v_i = 32
t = 0.017

dp = F * t               # impulse
v_f = v_i - dp / m       # final velocity

print(dp)
print(v_f)
# Out:
# 8.16
# -22.400000000000006

# %%
import math

m = 1.0
t = 0.045
h = 1.5
g = 9.81
v_f = 0

# from unit 2:  v_f^2 = v_i^2 + 2 * a * s

v_i = math.sqrt(2 * g * h) # final velocity after drop before hitting the ground

W = m * g
dp = m * (v_i - v_f)
F = dp / t

F
# Out:
# 120.55427546683417
